# %%
# !pip install pywin32

# %%
import win32com.client as wc

# %%
import win32com
import win32com.client as win32
xl_dis = win32.Dispatch("Excel.Application")
xl_dis
# Out:
# <COMObject Excel.Application>

# %%
xl_dis.Visible = 1

# %%
dir(win32com.gen_py.MicrosoftExcel16.0ObjectLibrary)
# Out:
#   File "<ipython-input-9-ad87093103e3>", line 1
#     dir(win32com.gen_py.MicrosoftExcel16.0ObjectLibrary)
#                                          ^
# SyntaxError: invalid syntax

# %%
import win32com.gen_py
# Out:
#   File "<ipython-input-10-2582071ab8c9>", line 1
#     help(win32com.gen_py.Microsoft Excel 16.0 Object Library._Worksheet)
#                                        ^
# SyntaxError: invalid syntax

# %%
# !python -m site
# Out:
# sys.path = [
#     'C:\\Users\\Murali\\PycharmProjects\\self try Projects',
#     'C:\\Users\\Murali\\anaconda3\\python37.zip',
#     'C:\\Users\\Murali\\anaconda3\\DLLs',
#     'C:\\Users\\Murali\\anaconda3\\lib',
#     'C:\\Users\\Murali\\anaconda3',
#     'C:\\Users\\Murali\\AppData\\Roaming\\Python\\Python37\\site-packages',
#     'C:\\Users\\Murali\\AppData\\Roaming\\Python\\Python37\\site-packages\\win32',
#     'C:\\Users\\Murali\\AppData\\Roaming\\Python\\Python37\\site-packages\\win32\\lib',
#     'C:\\Users\\Murali\\AppData\\Roaming\\Python\\Python37\\site-packages\\Pythonwin',
#     'C:\\Users\\Murali\\anaconda3\\lib\\site-packages',
#     'C:\\Users\\Murali\\anaconda3\\lib\\site-packages\\win32',
#     'C:\\Users\\Murali\\anaconda3\\lib\\site-packages\\win32\\lib',
#     'C:\\Users\\Murali\\anaconda3\\lib\\site-packages\\Pythonwin',
# ]
# USER_BASE: 'C:\\Users\\Murali\\AppData\\Roaming\\Python' (exists)
# ...

# %%
dir(win32com.client.Dispatch)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']
